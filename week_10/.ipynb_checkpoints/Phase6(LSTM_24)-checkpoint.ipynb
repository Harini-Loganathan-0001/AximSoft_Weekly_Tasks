# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
PJME_data = pd.read_csv(
    "PJME_phase2_preprocessed.csv",
    parse_dates=["Datetime"]
)

# %%
PJME_data = PJME_data.set_index("Datetime")

# Sort chronologically
PJME_data = PJME_data.sort_index()

print(PJME_data.shape)
print(PJME_data.head())
# Out:
# (145224, 15)
#                      PJME_MW  Hour  Day  Week  Month  DayOfWeek  IsWeekend  \
# Datetime
# 2002-01-08 01:00:00  29445.0     1    8     2      1          1          0
# 2002-01-08 02:00:00  28670.0     2    8     2      1          1          0
# 2002-01-08 03:00:00  28375.0     3    8     2      1          1          0
# 2002-01-08 04:00:00  28542.0     4    8     2      1          1          0
# 2002-01-08 05:00:00  29261.0     5    8     2      1          1          0
#
#                        Lag_1   Lag_24   Lag_48  Lag_168  Rolling_Mean_24  \
# Datetime
# 2002-01-08 01:00:00  31187.0  26862.0  27100.0  30393.0     33452.583333
# 2002-01-08 02:00:00  29445.0  25976.0  26097.0  29265.0     33560.208333
# 2002-01-08 03:00:00  28670.0  25641.0  25793.0  28357.0     33672.458333
# 2002-01-08 04:00:00  28375.0  25666.0  25657.0  27899.0     33786.375000
# 2002-01-08 05:00:00  28542.0  26328.0  25778.0  28057.0     33906.208333
#
#                      Rolling_Mean_168  Rolling_Std_24  Rolling_Std_168
# Datetime
# 2002-01-08 01:00:00      32519.511905     4559.767709      3857.950565
# 2002-01-08 02:00:00      32513.869048     4425.965952      3861.770954
# 2002-01-08 03:00:00      32510.327381     4256.159403      3865.039821
# 2002-01-08 04:00:00      32510.434524     4064.104959      3864.924245
# 2002-01-08 05:00:00      32514.261905     3851.076461      3860.646270

# %%
# Make sure data is chronological
PJME_data = PJME_data.sort_index()

n = len(PJME_data)

train_end = int(n * 0.70)
val_end = int(n * 0.85)

train = PJME_data.iloc[:train_end].copy()
validation = PJME_data.iloc[train_end:val_end].copy()
test = PJME_data.iloc[val_end:].copy()

print("Train:", train.shape)
print("Validation:", validation.shape)
print("Test:", test.shape)


print(train.index.min(), "to", train.index.max())
print(validation.index.min(), "to", validation.index.max())
print(test.index.min(), "to", test.index.max())
# Out:
# Train: (101656, 15)
# Validation: (21784, 15)
# Test: (21784, 15)
# 2002-01-08 01:00:00 to 2013-08-13 16:00:00
# 2013-08-13 17:00:00 to 2016-02-07 08:00:00
# 2016-02-07 09:00:00 to 2018-08-03 00:00:00

# %%
features = [
    "PJME_MW",
    "Hour",
    "Day",
    "Week",
    "Month",
    "DayOfWeek",
    "IsWeekend",
    "Lag_1",
    "Lag_24",
    "Lag_48",
    "Lag_168",
    "Rolling_Mean_24",
    "Rolling_Mean_168",
    "Rolling_Std_24",
    "Rolling_Std_168"
]

target = "PJME_MW"

X_train = train[features].copy()
X_val = validation[features].copy()
X_test = test[features].copy()

y_train = train[target].copy()
y_val = validation[target].copy()
y_test = test[target].copy()

print("X_train:", X_train.shape)
print("X_val:", X_val.shape)
print("X_test:", X_test.shape)
# Out:
# X_train: (101656, 15)
# X_val: (21784, 15)
# X_test: (21784, 15)

# %%
from sklearn.preprocessing import StandardScaler

feature_scaler = StandardScaler()
target_scaler = StandardScaler()

X_train_scaled = feature_scaler.fit_transform(X_train)
X_val_scaled = feature_scaler.transform(X_val)
X_test_scaled = feature_scaler.transform(X_test)

y_train_scaled = target_scaler.fit_transform(
    y_train.values.reshape(-1, 1)
)

y_val_scaled = target_scaler.transform(
    y_val.values.reshape(-1, 1)
)

y_test_scaled = target_scaler.transform(
    y_test.values.reshape(-1, 1)
)

print("Scaling completed.")
# Out:
# Scaling completed.

# %%
def create_sequences(X, y, input_steps=24, output_steps=24):

    X_seq = []
    y_seq = []

    for i in range(input_steps, len(X) - output_steps + 1):

        X_seq.append(
            X[i-input_steps:i]
        )

        y_seq.append(
            y[i:i+output_steps].flatten()
        )

    return np.array(X_seq), np.array(y_seq)


X_train_seq, y_train_seq = create_sequences(
    X_train_scaled,
    y_train_scaled,
    input_steps=24,
    output_steps=24
)

X_val_seq, y_val_seq = create_sequences(
    X_val_scaled,
    y_val_scaled,
    input_steps=24,
    output_steps=24
)

X_test_seq, y_test_seq = create_sequences(
    X_test_scaled,
    y_test_scaled,
    input_steps=24,
    output_steps=24
)


print("X_train:", X_train_seq.shape)
print("y_train:", y_train_seq.shape)

print("X_val:", X_val_seq.shape)
print("y_val:", y_val_seq.shape)

print("X_test:", X_test_seq.shape)
print("y_test:", y_test_seq.shape)
# Out:
# X_train: (101609, 24, 15)
# y_train: (101609, 24)
# X_val: (21737, 24, 15)
# y_val: (21737, 24)
# X_test: (21737, 24, 15)
# y_test: (21737, 24)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import EarlyStopping

# %%
lstm_model_es = Sequential([
    LSTM(
        64,
        input_shape=(24, 15),
        return_sequences=False
    ),

    Dense(64, activation="relu"),

    Dense(24)
])

lstm_model_es.compile(
    optimizer="adam",
    loss="mse",
    metrics=["mae"]
)

lstm_model_es.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 64)             │        20,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 24)             │         1,560 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 26,200 (102.34 KB)
#  Trainable params: 26,200 (102.34 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
early_stopping = EarlyStopping(
    monitor="val_loss",
    patience=3,
    restore_best_weights=True,
    verbose=1
)

# %%
lstm_history_es = lstm_model_es.fit(
    X_train_seq,
    y_train_seq,
    validation_data=(X_val_seq, y_val_seq),
    epochs=15,
    batch_size=64,
    callbacks=[early_stopping],
    verbose=1
)
# Out:
# Epoch 1/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 20s 11ms/step - loss: 0.1133 - mae: 0.2372 - val_loss: 0.0867 - val_mae: 0.2120
# Epoch 2/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 0.0695 - mae: 0.1886 - val_loss: 0.0823 - val_mae: 0.2059
# Epoch 3/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 0.0643 - mae: 0.1800 - val_loss: 0.0795 - val_mae: 0.2022
# Epoch 4/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 0.0610 - mae: 0.1745 - val_loss: 0.0786 - val_mae: 0.1992
# Epoch 5/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 20s 7ms/step - loss: 0.0584 - mae: 0.1703 - val_loss: 0.0782 - val_mae: 0.1999
# Epoch 6/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 0.0561 - mae: 0.1668 - val_loss: 0.0778 - val_mae: 0.1992
# Epoch 7/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 0.0543 - mae: 0.1640 - val_loss: 0.0759 - val_mae: 0.1953
# Epoch 8/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 0.0525 - mae: 0.1614 - val_loss: 0.0791 - val_mae: 0.1995
# Epoch 9/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 0.0510 - mae: 0.1592 - val_loss: 0.0779 - val_mae: 0.1953
# Epoch 10/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 0.0494 - mae: 0.1570 - val_loss: 0.0745 - val_mae: 0.1897
# Epoch 11/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 0.0476 - mae: 0.1543 - val_loss: 0.0810 - val_mae: 0.1998
# Epoch 12/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 0.0461 - mae: 0.1524 - val_loss: 0.0778 - val_mae: 0.1936
# Epoch 13/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 0.0446 - mae: 0.1502 - val_loss: 0.0789 - val_mae: 0.1958
# Epoch 13: early stopping
# Restoring model weights from the end of the best epoch: 10.

# %%
lstm_model_es_pred_scaled = lstm_model_es.predict(
    X_test_seq,
    batch_size=64
)
# Out:
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
lstm_pred = target_scaler.inverse_transform(
    lstm_model_es_pred_scaled.reshape(-1, 1)
).reshape(lstm_model_es_pred_scaled.shape)

lstm_actual = target_scaler.inverse_transform(
    y_test_seq.reshape(-1, 1)
).reshape(y_test_seq.shape)

# %%
from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    r2_score
)
lstm_mae = mean_absolute_error(
    lstm_actual.flatten(),
    lstm_pred.flatten()
)

lstm_rmse = np.sqrt(
    mean_squared_error(
        lstm_actual.flatten(),
        lstm_pred.flatten()
    )
)

lstm_mape = np.mean(
    np.abs(
        (lstm_actual.flatten() - lstm_pred.flatten())
        / lstm_actual.flatten()
    )
) * 100

lstm_r2 = r2_score(
    lstm_actual.flatten(),
    lstm_pred.flatten()
)

lstm_bias = np.mean(
    lstm_pred.flatten() - lstm_actual.flatten()
)

print("LSTM + Earlystopping")
print("MAE :", lstm_mae)
print("RMSE:", lstm_rmse)
print("MAPE:", lstm_mape)
print("R²  :", lstm_r2)
print("Bias:", lstm_bias)
# Out:
# LSTM + Earlystopping
# MAE : 1371.5942926832286
# RMSE: 1966.0505445799872
# MAPE: 4.308456332861411
# R²  : 0.9068668697446858
# Bias: -7.358135540154029

# %%
print("Epochs completed:", len(lstm_history_es.history["loss"]))
# Out:
# Epochs completed: 13

# %% [markdown]
# **Dropout**

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

lstm_dropout_model = Sequential([
    LSTM(
        64,
        input_shape=(24, 15),
        return_sequences=False
    ),

    Dropout(0.2),

    Dense(64, activation="relu"),

    Dropout(0.2),

    Dense(24)
])

lstm_dropout_model.compile(
    optimizer="adam",
    loss="mse",
    metrics=["mae"]
)

lstm_dropout_model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_1 (LSTM)                   │ (None, 64)             │        20,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 24)             │         1,560 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 26,200 (102.34 KB)
#  Trainable params: 26,200 (102.34 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
lstm_history_dropout = lstm_dropout_model.fit(
    X_train_seq,
    y_train_seq,
    validation_data=(X_val_seq, y_val_seq),
    epochs=15,
    batch_size=64,
    verbose=1
)
# Out:
# Epoch 1/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 25s 15ms/step - loss: 0.1857 - mae: 0.3227 - val_loss: 0.0968 - val_mae: 0.2319
# Epoch 2/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 34s 11ms/step - loss: 0.1202 - mae: 0.2625 - val_loss: 0.0874 - val_mae: 0.2196
# Epoch 3/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 21s 13ms/step - loss: 0.1124 - mae: 0.2525 - val_loss: 0.0841 - val_mae: 0.2115
# Epoch 4/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - loss: 0.1092 - mae: 0.2486 - val_loss: 0.0816 - val_mae: 0.2085
# Epoch 5/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 21s 13ms/step - loss: 0.1065 - mae: 0.2451 - val_loss: 0.0817 - val_mae: 0.2103
# Epoch 6/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - loss: 0.1048 - mae: 0.2431 - val_loss: 0.0793 - val_mae: 0.2084
# Epoch 7/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 0.1030 - mae: 0.2408 - val_loss: 0.0846 - val_mae: 0.2148
# Epoch 8/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - loss: 0.1019 - mae: 0.2399 - val_loss: 0.0803 - val_mae: 0.2089
# Epoch 9/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 0.1004 - mae: 0.2382 - val_loss: 0.0799 - val_mae: 0.2077
# Epoch 10/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 21s 7ms/step - loss: 0.0996 - mae: 0.2371 - val_loss: 0.0813 - val_mae: 0.2091
# Epoch 11/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 0.0983 - mae: 0.2357 - val_loss: 0.0774 - val_mae: 0.2011
# Epoch 12/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 0.0978 - mae: 0.2351 - val_loss: 0.0759 - val_mae: 0.1989
# Epoch 13/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 0.0970 - mae: 0.2341 - val_loss: 0.0774 - val_mae: 0.2028
# Epoch 14/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - loss: 0.0960 - mae: 0.2329 - val_loss: 0.0816 - val_mae: 0.2137
# Epoch 15/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 0.0957 - mae: 0.2327 - val_loss: 0.0771 - val_mae: 0.2025

# %%
dropout_pred_scaled = lstm_dropout_model.predict(
    X_test_seq,
    batch_size=64
)
# Out:
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
dropout_pred = target_scaler.inverse_transform(
    dropout_pred_scaled.reshape(-1, 1)
).reshape(dropout_pred_scaled.shape)

dropout_actual = target_scaler.inverse_transform(
    y_test_seq.reshape(-1, 1)
).reshape(y_test_seq.shape)

# %%
mae = mean_absolute_error(
    dropout_actual.flatten(),
    dropout_pred.flatten()
)

rmse = np.sqrt(
    mean_squared_error(
        dropout_actual.flatten(),
        dropout_pred.flatten()
    )
)

mape = np.mean(
    np.abs(
        (dropout_actual.flatten() - dropout_pred.flatten())
        / dropout_actual.flatten()
    )
) * 100

r2 = r2_score(
    dropout_actual.flatten(),
    dropout_pred.flatten()
)

bias = np.mean(
    dropout_pred.flatten() -
    dropout_actual.flatten()
)

print("== LSTM + DROPOUT ==")
print("MAE :", mae)
print("RMSE:", rmse)
print("MAPE:", mape)
print("R²  :", r2)
print("Bias:", bias)
# Out:
# == LSTM + DROPOUT ==
# MAE : 1435.9869157270186
# RMSE: 1978.9195155859854
# MAPE: 4.598822519549131
# R²  : 0.9056436559322364
# Bias: 292.5129554768307

# %% [markdown]
# **Batch Normalization**

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import  BatchNormalization

lstm_bn_model = Sequential([
    LSTM(
        64,
        input_shape=(24, 15)
    ),

    BatchNormalization(),

    Dense(64, activation="relu"),

    BatchNormalization(),

    Dense(24)
])

lstm_bn_model.compile(
    optimizer="adam",
    loss="mse",
    metrics=["mae"]
)

lstm_bn_model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_2 (LSTM)                   │ (None, 64)             │        20,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 24)             │         1,560 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 26,712 (104.34 KB)
#  Trainable params: 26,456 (103.34 KB)
#  Non-trainable params: 256 (1.00 KB)

# %%
history_bn = lstm_bn_model.fit(
    X_train_seq,
    y_train_seq,
    validation_data=(X_val_seq, y_val_seq),
    epochs=15,
    batch_size=64,
    verbose=1
)
# Out:
# Epoch 1/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - loss: 0.1691 - mae: 0.3024 - val_loss: 0.0956 - val_mae: 0.2290
# Epoch 2/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - loss: 0.0959 - mae: 0.2319 - val_loss: 0.0920 - val_mae: 0.2190
# Epoch 3/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - loss: 0.0873 - mae: 0.2206 - val_loss: 0.0833 - val_mae: 0.2054
# Epoch 4/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - loss: 0.0827 - mae: 0.2143 - val_loss: 0.0772 - val_mae: 0.1998
# Epoch 5/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - loss: 0.0791 - mae: 0.2094 - val_loss: 0.0751 - val_mae: 0.1966
# Epoch 6/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - loss: 0.0768 - mae: 0.2063 - val_loss: 0.0794 - val_mae: 0.2010
# Epoch 7/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - loss: 0.0746 - mae: 0.2032 - val_loss: 0.0778 - val_mae: 0.1991
# Epoch 8/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - loss: 0.0728 - mae: 0.2009 - val_loss: 0.0781 - val_mae: 0.1969
# Epoch 9/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - loss: 0.0714 - mae: 0.1992 - val_loss: 0.0757 - val_mae: 0.1933
# Epoch 10/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - loss: 0.0697 - mae: 0.1975 - val_loss: 0.0778 - val_mae: 0.2000
# Epoch 11/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - loss: 0.0672 - mae: 0.1942 - val_loss: 0.0791 - val_mae: 0.1996
# Epoch 12/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - loss: 0.0665 - mae: 0.1935 - val_loss: 0.0829 - val_mae: 0.2033
# Epoch 13/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - loss: 0.0651 - mae: 0.1916 - val_loss: 0.0787 - val_mae: 0.1996
# Epoch 14/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - loss: 0.0632 - mae: 0.1892 - val_loss: 0.0840 - val_mae: 0.2018
# Epoch 15/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - loss: 0.0616 - mae: 0.1872 - val_loss: 0.0841 - val_mae: 0.2042

# %%
bn_pred_scaled = lstm_bn_model.predict(
    X_test_seq,
    batch_size=64
)
# Out:
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step

# %%
lstm_bn_pred = target_scaler.inverse_transform(
    bn_pred_scaled.reshape(-1, 1)
).reshape(bn_pred_scaled.shape)

lstm_bn_actual = target_scaler.inverse_transform(
    y_test_seq.reshape(-1, 1)
).reshape(y_test_seq.shape)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

mae = mean_absolute_error(
    lstm_bn_actual.flatten(),
    lstm_bn_pred.flatten()
)

rmse = np.sqrt(
    mean_squared_error(
        lstm_bn_actual.flatten(),
        lstm_bn_pred.flatten()
    )
)

mape = np.mean(
    np.abs(
        (lstm_bn_actual.flatten() - lstm_bn_pred.flatten())
        / lstm_bn_actual.flatten()
    )
) * 100

r2 = r2_score(
    lstm_bn_actual.flatten(),
    lstm_bn_pred.flatten()
)

bias = np.mean(
    lstm_bn_pred.flatten() - lstm_bn_actual.flatten()
)

print("== LSTM + Batch ==")
print("MAE :", mae)
print("RMSE:", rmse)
print("MAPE:", mape)
print("R²  :", r2)
print("Bias:", bias)
# Out:
# == LSTM + Batch ==
# MAE : 1497.3504537681347
# RMSE: 2152.169810189539
# MAPE: 4.745313523054921
# R²  : 0.8883990446168706
# Bias: 331.9928530416228

# %% [markdown]
# **RMSPROP**

# %%
from tensorflow.keras.optimizers import RMSprop

lstm_rmsprop = Sequential([
    LSTM(
        64,
        input_shape=(24, 15),
        return_sequences=False
    ),

    Dense(64, activation="relu"),

    Dense(24)
])

lstm_rmsprop.compile(
    optimizer=RMSprop(
        learning_rate=0.001
    ),
    loss="mse",
    metrics=["mae"]
)

lstm_rmsprop.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_3 (LSTM)                   │ (None, 64)             │        20,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 24)             │         1,560 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 26,200 (102.34 KB)
#  Trainable params: 26,200 (102.34 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history_rmsprop = lstm_rmsprop.fit(
    X_train_seq,
    y_train_seq,
    validation_data=(X_val_seq, y_val_seq),
    epochs=15,
    batch_size=64,
    verbose=1
)
# Out:
# Epoch 1/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 0.1152 - mae: 0.2425 - val_loss: 0.0952 - val_mae: 0.2274
# Epoch 2/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 0.0721 - mae: 0.1923 - val_loss: 0.0823 - val_mae: 0.2080
# Epoch 3/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 0.0661 - mae: 0.1828 - val_loss: 0.0807 - val_mae: 0.2048
# Epoch 4/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 0.0625 - mae: 0.1768 - val_loss: 0.0799 - val_mae: 0.2029
# Epoch 5/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 0.0599 - mae: 0.1726 - val_loss: 0.0797 - val_mae: 0.2019
# Epoch 6/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 0.0580 - mae: 0.1693 - val_loss: 0.0761 - val_mae: 0.1943
# Epoch 7/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.0564 - mae: 0.1666 - val_loss: 0.0786 - val_mae: 0.1965
# Epoch 8/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 0.0551 - mae: 0.1646 - val_loss: 0.0828 - val_mae: 0.2062
# Epoch 9/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 0.0535 - mae: 0.1624 - val_loss: 0.0867 - val_mae: 0.2079
# Epoch 10/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 0.0523 - mae: 0.1604 - val_loss: 0.0812 - val_mae: 0.1998
# Epoch 11/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.0510 - mae: 0.1585 - val_loss: 0.0759 - val_mae: 0.1933
# Epoch 12/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 0.0496 - mae: 0.1566 - val_loss: 0.0830 - val_mae: 0.2044
# Epoch 13/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 0.0484 - mae: 0.1548 - val_loss: 0.0794 - val_mae: 0.1999
# Epoch 14/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 0.0471 - mae: 0.1530 - val_loss: 0.0797 - val_mae: 0.1962
# Epoch 15/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 0.0457 - mae: 0.1512 - val_loss: 0.0836 - val_mae: 0.2010

# %%
rmsprop_pred_scaled = lstm_rmsprop.predict(
    X_test_seq,
    batch_size=64
)

print("Prediction shape:", rmsprop_pred_scaled.shape)
# Out:
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Prediction shape: (21737, 24)

# %%
rmsprop_pred = target_scaler.inverse_transform(
    rmsprop_pred_scaled.reshape(-1, 1)
).reshape(rmsprop_pred_scaled.shape)

rmsprop_actual = target_scaler.inverse_transform(
    y_test_seq.reshape(-1, 1)
).reshape(y_test_seq.shape)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

rmsprop_mae = mean_absolute_error(
    rmsprop_actual.flatten(),
    rmsprop_pred.flatten()
)

rmsprop_rmse = np.sqrt(
    mean_squared_error(
        rmsprop_actual.flatten(),
        rmsprop_pred.flatten()
    )
)

rmsprop_mape = np.mean(
    np.abs(
        (rmsprop_actual.flatten() - rmsprop_pred.flatten())
        / rmsprop_actual.flatten()
    )
) * 100

rmsprop_r2 = r2_score(
    rmsprop_actual.flatten(),
    rmsprop_pred.flatten()
)

rmsprop_bias = np.mean(
    rmsprop_pred.flatten() -
    rmsprop_actual.flatten()
)

print("=== LSTM + RMSPROP ===")
print("MAE :", rmsprop_mae)
print("RMSE:", rmsprop_rmse)
print("MAPE:", rmsprop_mape)
print("R²  :", rmsprop_r2)
print("Bias:", rmsprop_bias)
# Out:
# === LSTM + RMSPROP ===
# MAE : 1448.469909610875
# RMSE: 2081.2529851468817
# MAPE: 4.552259525724164
# R²  : 0.8956326659487768
# Bias: 116.74554798932144

# %% [markdown]
# **SGD**

# %%
from tensorflow.keras.optimizers import SGD

lstm_sgd = Sequential([
    LSTM(
        64,
        input_shape=(24, 15),
        return_sequences=False
    ),

    Dense(64, activation="relu"),

    Dense(24)
])

lstm_sgd.compile(
    optimizer=SGD(
        learning_rate=0.001,
        momentum=0.9
    ),
    loss="mse",
    metrics=["mae"]
)

lstm_sgd.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_4 (LSTM)                   │ (None, 64)             │        20,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 24)             │         1,560 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 26,200 (102.34 KB)
#  Trainable params: 26,200 (102.34 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history_sgd = lstm_sgd.fit(
    X_train_seq,
    y_train_seq,
    validation_data=(X_val_seq, y_val_seq),
    epochs=15,
    batch_size=64,
    verbose=1
)
# Out:
# Epoch 1/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 0.5893 - mae: 0.5945 - val_loss: 0.3187 - val_mae: 0.4510
# Epoch 2/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 0.2298 - mae: 0.3808 - val_loss: 0.1936 - val_mae: 0.3472
# Epoch 3/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 0.1703 - mae: 0.3254 - val_loss: 0.1656 - val_mae: 0.3175
# Epoch 4/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 0.1460 - mae: 0.2984 - val_loss: 0.1470 - val_mae: 0.2959
# Epoch 5/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 0.1286 - mae: 0.2771 - val_loss: 0.1346 - val_mae: 0.2809
# Epoch 6/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 0.1166 - mae: 0.2614 - val_loss: 0.1262 - val_mae: 0.2699
# Epoch 7/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 0.1084 - mae: 0.2500 - val_loss: 0.1194 - val_mae: 0.2600
# Epoch 8/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 0.1026 - mae: 0.2418 - val_loss: 0.1155 - val_mae: 0.2547
# Epoch 9/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.0983 - mae: 0.2355 - val_loss: 0.1129 - val_mae: 0.2501
# Epoch 10/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 0.0949 - mae: 0.2306 - val_loss: 0.1073 - val_mae: 0.2444
# Epoch 11/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 0.0922 - mae: 0.2265 - val_loss: 0.1059 - val_mae: 0.2413
# Epoch 12/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 0.0899 - mae: 0.2230 - val_loss: 0.1033 - val_mae: 0.2388
# Epoch 13/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 0.0880 - mae: 0.2201 - val_loss: 0.1025 - val_mae: 0.2362
# Epoch 14/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 0.0863 - mae: 0.2175 - val_loss: 0.0998 - val_mae: 0.2334
# Epoch 15/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.0847 - mae: 0.2151 - val_loss: 0.0989 - val_mae: 0.2317

# %%
sgd_pred_scaled = lstm_sgd.predict(
    X_test_seq,
    batch_size=64
)

print("Prediction shape:", sgd_pred_scaled.shape)
# Out:
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Prediction shape: (21737, 24)

# %%
sgd_pred = target_scaler.inverse_transform(
    sgd_pred_scaled.reshape(-1, 1)
).reshape(sgd_pred_scaled.shape)

sgd_actual = target_scaler.inverse_transform(
    y_test_seq.reshape(-1, 1)
).reshape(y_test_seq.shape)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

sgd_mae = mean_absolute_error(
    sgd_actual.flatten(),
    sgd_pred.flatten()
)

sgd_rmse = np.sqrt(
    mean_squared_error(
        sgd_actual.flatten(),
        sgd_pred.flatten()
    )
)

sgd_mape = np.mean(
    np.abs(
        (sgd_actual.flatten() - sgd_pred.flatten())
        / sgd_actual.flatten()
    )
) * 100

sgd_r2 = r2_score(
    sgd_actual.flatten(),
    sgd_pred.flatten()
)

sgd_bias = np.mean(
    sgd_pred.flatten() -
    sgd_actual.flatten()
)
print("=== LSTM + SGD ===")
print("MAE :", sgd_mae)
print("RMSE:", sgd_rmse)
print("MAPE:", sgd_mape)
print("R²  :", sgd_r2)
print("Bias:", sgd_bias)
# Out:
# === LSTM + SGD ===
# MAE : 1619.9055719913351
# RMSE: 2202.2063143118253
# MAPE: 5.131375074640218
# R²  : 0.8831494261356626
# Bias: 41.03663592316552

# %% [markdown]
# Learning Rate Scheduling

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.optimizers import RMSprop

lstm_lr = Sequential([
    LSTM(
        64,
        input_shape=(24, 15)
    ),

    Dense(64, activation="relu"),

    Dense(24)
])

lstm_lr.compile(
    optimizer=RMSprop(learning_rate=0.001),
    loss="mse",
    metrics=["mae"]
)

lr_scheduler = ReduceLROnPlateau(
    monitor="val_loss",
    factor=0.2,
    patience=2,
    min_lr=1e-6,
    verbose=1
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
history_lr = lstm_lr.fit(
    X_train_seq,
    y_train_seq,
    validation_data=(X_val_seq, y_val_seq),
    epochs=15,
    batch_size=64,
    callbacks=[lr_scheduler],
    verbose=1
)
# Out:
# Epoch 1/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 0.1116 - mae: 0.2388 - val_loss: 0.0931 - val_mae: 0.2257 - learning_rate: 0.0010
# Epoch 2/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 0.0713 - mae: 0.1911 - val_loss: 0.0894 - val_mae: 0.2155 - learning_rate: 0.0010
# Epoch 3/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 0.0654 - mae: 0.1814 - val_loss: 0.0770 - val_mae: 0.1981 - learning_rate: 0.0010
# Epoch 4/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 0.0618 - mae: 0.1756 - val_loss: 0.0809 - val_mae: 0.2045 - learning_rate: 0.0010
# Epoch 5/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.0592 - mae: 0.1714 - val_loss: 0.0758 - val_mae: 0.1971 - learning_rate: 0.0010
# Epoch 6/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 0.0574 - mae: 0.1684 - val_loss: 0.0825 - val_mae: 0.2067 - learning_rate: 0.0010
# Epoch 7/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0557 - mae: 0.1661
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 0.0555 - mae: 0.1655 - val_loss: 0.0852 - val_mae: 0.2096 - learning_rate: 0.0010
# Epoch 8/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 0.0503 - mae: 0.1566 - val_loss: 0.0738 - val_mae: 0.1913 - learning_rate: 2.0000e-04
# Epoch 9/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.0495 - mae: 0.1555 - val_loss: 0.0738 - val_mae: 0.1919 - learning_rate: 2.0000e-04
# Epoch 10/15
# 1579/1588 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0483 - mae: 0.1539
# Epoch 10: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 0.0489 - mae: 0.1547 - val_loss: 0.0748 - val_mae: 0.1928 - learning_rate: 2.0000e-04
# Epoch 11/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 0.0479 - mae: 0.1529 - val_loss: 0.0750 - val_mae: 0.1930 - learning_rate: 4.0000e-05
# Epoch 12/15
# 1587/1588 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0478 - mae: 0.1528
# Epoch 12: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 0.0477 - mae: 0.1526 - val_loss: 0.0753 - val_mae: 0.1931 - learning_rate: 4.0000e-05
# Epoch 13/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.0474 - mae: 0.1522 - val_loss: 0.0751 - val_mae: 0.1927 - learning_rate: 8.0000e-06
# Epoch 14/15
# 1580/1588 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0475 - mae: 0.1523
# Epoch 14: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 0.0474 - mae: 0.1521 - val_loss: 0.0752 - val_mae: 0.1929 - learning_rate: 8.0000e-06
# Epoch 15/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 0.0473 - mae: 0.1520 - val_loss: 0.0751 - val_mae: 0.1927 - learning_rate: 1.6000e-06

# %%
lr_pred_scaled = lstm_lr.predict(
    X_test_seq,
    batch_size=64
)

print("Prediction shape:", lr_pred_scaled.shape)
# Out:
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Prediction shape: (21737, 24)

# %%
lr_pred = target_scaler.inverse_transform(
    lr_pred_scaled.reshape(-1, 1)
).reshape(lr_pred_scaled.shape)

lr_actual = target_scaler.inverse_transform(
    y_test_seq.reshape(-1, 1)
).reshape(y_test_seq.shape)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

lr_mae = mean_absolute_error(
    lr_actual.flatten(),
    lr_pred.flatten()
)

lr_rmse = np.sqrt(
    mean_squared_error(
        lr_actual.flatten(),
        lr_pred.flatten()
    )
)

lr_mape = np.mean(
    np.abs(
        (lr_actual.flatten() - lr_pred.flatten())
        / lr_actual.flatten()
    )
) * 100

lr_r2 = r2_score(
    lr_actual.flatten(),
    lr_pred.flatten()
)

lr_bias = np.mean(
    lr_pred.flatten() -
    lr_actual.flatten()
)

print("==== LSTM + RMSPROP + LearningRate ====")
print("MAE :", lr_mae)
print("RMSE:", lr_rmse)
print("MAPE:", lr_mape)
print("R²  :", lr_r2)
print("Bias:", lr_bias)
# Out:
# ==== LSTM + RMSPROP + LearningRate ====
# MAE : 1410.2147051636646
# RMSE: 1998.6879593345095
# MAPE: 4.457815486714933
# R²  : 0.9037490920798036
# Bias: 251.24647654060593

# %% [markdown]
# **Layers**

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

lstm_deep = Sequential([

    LSTM(
        64,
        return_sequences=True,
        input_shape=(24, 15)
    ),

    LSTM(
        32,
        return_sequences=False
    ),

    Dense(
        64,
        activation="relu"
    ),

    Dense(24)
])

lstm_deep.compile(
    optimizer="adam",
    loss="mse",
    metrics=["mae"]
)

lstm_deep.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_6 (LSTM)                   │ (None, 24, 64)         │        20,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_7 (LSTM)                   │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 64)             │         2,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 24)             │         1,560 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 36,568 (142.84 KB)
#  Trainable params: 36,568 (142.84 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history_deep = lstm_deep.fit(
    X_train_seq,
    y_train_seq,
    validation_data=(X_val_seq, y_val_seq),
    epochs=15,
    batch_size=64,
    verbose=1
)
# Out:
# Epoch 1/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - loss: 0.1230 - mae: 0.2485 - val_loss: 0.0927 - val_mae: 0.2203
# Epoch 2/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - loss: 0.0702 - mae: 0.1911 - val_loss: 0.0841 - val_mae: 0.2126
# Epoch 3/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - loss: 0.0628 - mae: 0.1796 - val_loss: 0.0806 - val_mae: 0.2051
# Epoch 4/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - loss: 0.0579 - mae: 0.1721 - val_loss: 0.0818 - val_mae: 0.2053
# Epoch 5/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - loss: 0.0541 - mae: 0.1664 - val_loss: 0.0774 - val_mae: 0.1976
# Epoch 6/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - loss: 0.0505 - mae: 0.1611 - val_loss: 0.0879 - val_mae: 0.2119
# Epoch 7/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - loss: 0.0471 - mae: 0.1562 - val_loss: 0.0853 - val_mae: 0.2088
# Epoch 8/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - loss: 0.0436 - mae: 0.1511 - val_loss: 0.0866 - val_mae: 0.2091
# Epoch 9/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - loss: 0.0406 - mae: 0.1466 - val_loss: 0.0829 - val_mae: 0.2021
# Epoch 10/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - loss: 0.0377 - mae: 0.1420 - val_loss: 0.0888 - val_mae: 0.2092
# Epoch 11/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - loss: 0.0353 - mae: 0.1380 - val_loss: 0.0868 - val_mae: 0.2080
# Epoch 12/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - loss: 0.0332 - mae: 0.1344 - val_loss: 0.0854 - val_mae: 0.2038
# Epoch 13/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - loss: 0.0314 - mae: 0.1312 - val_loss: 0.0885 - val_mae: 0.2060
# Epoch 14/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - loss: 0.0299 - mae: 0.1282 - val_loss: 0.0901 - val_mae: 0.2091
# Epoch 15/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - loss: 0.0281 - mae: 0.1247 - val_loss: 0.0933 - val_mae: 0.2097

# %%
deep_pred_scaled = lstm_deep.predict(
    X_test_seq,
    batch_size=64
)
print("Prediction shape:", deep_pred_scaled.shape)
# Out:
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Prediction shape: (21737, 24)

# %%
deep_pred = target_scaler.inverse_transform(
    deep_pred_scaled.reshape(-1, 1)
).reshape(deep_pred_scaled.shape)

deep_actual = target_scaler.inverse_transform(
    y_test_seq.reshape(-1, 1)
).reshape(y_test_seq.shape)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

deep_mae = mean_absolute_error(
    deep_actual.flatten(),
    deep_pred.flatten()
)

deep_rmse = np.sqrt(
    mean_squared_error(
        deep_actual.flatten(),
        deep_pred.flatten()
    )
)

deep_mape = np.mean(
    np.abs(
        (deep_actual.flatten() - deep_pred.flatten())
        / deep_actual.flatten()
    )
) * 100

deep_r2 = r2_score(
    deep_actual.flatten(),
    deep_pred.flatten()
)

deep_bias = np.mean(
    deep_pred.flatten() -
    deep_actual.flatten()
)

print("==== LSTM + Layers ==========")
print("MAE :", deep_mae)
print("RMSE:", deep_rmse)
print("MAPE:", deep_mape)
print("R²  :", deep_r2)
print("Bias:", deep_bias)
# Out:
# ==== LSTM + Layers ==========
# MAE : 1519.6695388148364
# RMSE: 2214.7553001711126
# MAPE: 4.766964569656305
# R²  : 0.8818139162795469
# Bias: 206.9655315675689

# %% [markdown]
# **Neurons**

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

lstm_128 = Sequential([

    LSTM(
        128,
        input_shape=(24, 15)
    ),

    Dense(
        64,
        activation="relu"
    ),

    Dense(24)
])

lstm_128.compile(
    optimizer="adam",
    loss="mse",
    metrics=["mae"]
)

lstm_128.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_8 (LSTM)                   │ (None, 128)            │        73,728 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ (None, 24)             │         1,560 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 83,544 (326.34 KB)
#  Trainable params: 83,544 (326.34 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history_128 = lstm_128.fit(
    X_train_seq,
    y_train_seq,
    validation_data=(X_val_seq, y_val_seq),
    epochs=15,
    batch_size=64,
    verbose=1
)
# Out:
# Epoch 1/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - loss: 0.1013 - mae: 0.2260 - val_loss: 0.0873 - val_mae: 0.2146
# Epoch 2/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 0.0661 - mae: 0.1831 - val_loss: 0.0795 - val_mae: 0.2031
# Epoch 3/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 0.0600 - mae: 0.1731 - val_loss: 0.0806 - val_mae: 0.2017
# Epoch 4/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 0.0554 - mae: 0.1661 - val_loss: 0.0772 - val_mae: 0.1954
# Epoch 5/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 0.0514 - mae: 0.1602 - val_loss: 0.0802 - val_mae: 0.1977
# Epoch 6/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 0.0471 - mae: 0.1540 - val_loss: 0.0838 - val_mae: 0.2012
# Epoch 7/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 0.0423 - mae: 0.1469 - val_loss: 0.0838 - val_mae: 0.2005
# Epoch 8/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 0.0378 - mae: 0.1401 - val_loss: 0.0852 - val_mae: 0.2019
# Epoch 9/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 0.0340 - mae: 0.1340 - val_loss: 0.0929 - val_mae: 0.2109
# Epoch 10/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 0.0303 - mae: 0.1274 - val_loss: 0.0878 - val_mae: 0.2044
# Epoch 11/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 0.0273 - mae: 0.1217 - val_loss: 0.0877 - val_mae: 0.2033
# Epoch 12/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 0.0247 - mae: 0.1163 - val_loss: 0.0920 - val_mae: 0.2071
# Epoch 13/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 0.0225 - mae: 0.1116 - val_loss: 0.0956 - val_mae: 0.2114
# Epoch 14/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 0.0208 - mae: 0.1077 - val_loss: 0.0964 - val_mae: 0.2116
# Epoch 15/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 0.0194 - mae: 0.1044 - val_loss: 0.0968 - val_mae: 0.2129

# %%
lstm128_pred_scaled = lstm_128.predict(
    X_test_seq,
    batch_size=64
)

print("Prediction shape:", lstm128_pred_scaled.shape)
# Out:
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Prediction shape: (21737, 24)

# %%
lstm128_pred = target_scaler.inverse_transform(
    lstm128_pred_scaled.reshape(-1, 1)
).reshape(lstm128_pred_scaled.shape)

lstm128_actual = target_scaler.inverse_transform(
    y_test_seq.reshape(-1, 1)
).reshape(y_test_seq.shape)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

lstm128_mae = mean_absolute_error(
    lstm128_actual.flatten(),
    lstm128_pred.flatten()
)

lstm128_rmse = np.sqrt(
    mean_squared_error(
        lstm_actual.flatten(),
        lstm_pred.flatten()
    )
)

lstm128_mape = np.mean(
    np.abs(
        (lstm128_actual.flatten() - lstm128_pred.flatten())
        / lstm128_actual.flatten()
    )
) * 100

lstm128_r2 = r2_score(
    lstm128_actual.flatten(),
    lstm128_pred.flatten()
)

lstm128_bias = np.mean(
    lstm128_pred.flatten() -
    lstm128_actual.flatten()
)

print("=== LSTM 128 NEURONS ===")
print("MAE :", lstm128_mae)
print("RMSE:", lstm128_rmse)
print("MAPE:", lstm128_mape)
print("R²  :", lstm128_r2)
print("Bias:", lstm128_bias)
# Out:
# === LSTM 128 NEURONS ===
# MAE : 1506.9126826623833
# RMSE: 1966.0505445799872
# MAPE: 4.712792519674344
# R²  : 0.8858572879605617
# Bias: 126.27973308856599

# %% [markdown]
# 32 **neurons**

# %%
lstm_32 = Sequential([
    LSTM(
        32,
        input_shape=(24, 15)
    ),

    Dense(64, activation="relu"),

    Dense(24)
])

lstm_32.compile(
    optimizer="adam",
    loss="mse",
    metrics=["mae"]
)

lstm_32.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_9 (LSTM)                   │ (None, 32)             │         6,144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ (None, 64)             │         2,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_17 (Dense)                │ (None, 24)             │         1,560 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 9,816 (38.34 KB)
#  Trainable params: 9,816 (38.34 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history_32 = lstm_32.fit(
    X_train_seq,
    y_train_seq,
    validation_data=(X_val_seq, y_val_seq),
    epochs=15,
    batch_size=64,
    verbose=1
)
# Out:
# Epoch 1/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - loss: 0.1406 - mae: 0.2666 - val_loss: 0.0930 - val_mae: 0.2244
# Epoch 2/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 0.0744 - mae: 0.1970 - val_loss: 0.0852 - val_mae: 0.2100
# Epoch 3/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 0.0686 - mae: 0.1872 - val_loss: 0.0826 - val_mae: 0.2064
# Epoch 4/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 0.0654 - mae: 0.1817 - val_loss: 0.0780 - val_mae: 0.2000
# Epoch 5/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 0.0631 - mae: 0.1778 - val_loss: 0.0801 - val_mae: 0.2044
# Epoch 6/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 0.0615 - mae: 0.1752 - val_loss: 0.0747 - val_mae: 0.1942
# Epoch 7/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 0.0601 - mae: 0.1729 - val_loss: 0.0786 - val_mae: 0.2033
# Epoch 8/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 0.0588 - mae: 0.1707 - val_loss: 0.0768 - val_mae: 0.1976
# Epoch 9/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 0.0578 - mae: 0.1692 - val_loss: 0.0763 - val_mae: 0.1974
# Epoch 10/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 0.0569 - mae: 0.1678 - val_loss: 0.0736 - val_mae: 0.1927
# Epoch 11/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 0.0559 - mae: 0.1662 - val_loss: 0.0756 - val_mae: 0.1966
# Epoch 12/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 21s 7ms/step - loss: 0.0552 - mae: 0.1652 - val_loss: 0.0754 - val_mae: 0.1949
# Epoch 13/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 0.0544 - mae: 0.1641 - val_loss: 0.0721 - val_mae: 0.1901
# Epoch 14/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 0.0537 - mae: 0.1629 - val_loss: 0.0747 - val_mae: 0.1933
# Epoch 15/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 0.0530 - mae: 0.1619 - val_loss: 0.0804 - val_mae: 0.2012

# %%
lstm32_pred_scaled = lstm_32.predict(
    X_test_seq,
    batch_size=64
)

print("Prediction shape:", lstm32_pred_scaled.shape)
# Out:
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Prediction shape: (21737, 24)

# %%
lstm32_pred = target_scaler.inverse_transform(
    lstm32_pred_scaled.reshape(-1, 1)
).reshape(lstm32_pred_scaled.shape)

lstm32_actual = target_scaler.inverse_transform(
    y_test_seq.reshape(-1, 1)
).reshape(y_test_seq.shape)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

lstm32_mae = mean_absolute_error(
    lstm32_actual.flatten(),
    lstm32_pred.flatten()
)

lstm32_rmse = np.sqrt(
    mean_squared_error(
        lstm32_actual.flatten(),
        lstm32_pred.flatten()
    )
)

lstm32_mape = np.mean(
    np.abs(
        (lstm32_actual.flatten() - lstm32_pred.flatten())
        / lstm32_actual.flatten()
    )
) * 100

lstm32_r2 = r2_score(
    lstm32_actual.flatten(),
    lstm32_pred.flatten()
)

lstm32_bias = np.mean(
    lstm32_pred.flatten() -
    lstm32_actual.flatten()
)

print("=== LSTM 32 NEURONS ===")
print("MAE :", lstm32_mae)
print("RMSE:", lstm32_rmse)
print("MAPE:", lstm32_mape)
print("R²  :", lstm32_r2)
print("Bias:", lstm32_bias)
# Out:
# === LSTM 32 NEURONS ===
# MAE : 1464.3484043174512
# RMSE: 2061.1117565050754
# MAPE: 4.648727127650058
# R²  : 0.8976429116340158
# Bias: 341.37884747145324

# %% [markdown]
# Batch Size(32)

# %%
lstm_batch32 = Sequential([
    LSTM(64, input_shape=(24, 15)),
    Dense(64, activation="relu"),
    Dense(24)
])

lstm_batch32.compile(
    optimizer="adam",
    loss="mse",
    metrics=["mae"]
)

history_batch32 = lstm_batch32.fit(
    X_train_seq,
    y_train_seq,
    validation_data=(X_val_seq, y_val_seq),
    epochs=15,
    batch_size=32,
    verbose=1
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/15
# 3176/3176 ━━━━━━━━━━━━━━━━━━━━ 23s 7ms/step - loss: 0.1005 - mae: 0.2246 - val_loss: 0.0841 - val_mae: 0.2091
# Epoch 2/15
# 3176/3176 ━━━━━━━━━━━━━━━━━━━━ 21s 7ms/step - loss: 0.0682 - mae: 0.1856 - val_loss: 0.0785 - val_mae: 0.1982
# Epoch 3/15
# 3176/3176 ━━━━━━━━━━━━━━━━━━━━ 20s 6ms/step - loss: 0.0625 - mae: 0.1763 - val_loss: 0.0778 - val_mae: 0.1990
# Epoch 4/15
# 3176/3176 ━━━━━━━━━━━━━━━━━━━━ 21s 7ms/step - loss: 0.0588 - mae: 0.1704 - val_loss: 0.0791 - val_mae: 0.2010
# Epoch 5/15
# 3176/3176 ━━━━━━━━━━━━━━━━━━━━ 20s 6ms/step - loss: 0.0561 - mae: 0.1662 - val_loss: 0.0768 - val_mae: 0.1951
# Epoch 6/15
# 3176/3176 ━━━━━━━━━━━━━━━━━━━━ 20s 6ms/step - loss: 0.0537 - mae: 0.1627 - val_loss: 0.0742 - val_mae: 0.1912
# Epoch 7/15
# 3176/3176 ━━━━━━━━━━━━━━━━━━━━ 22s 7ms/step - loss: 0.0512 - mae: 0.1592 - val_loss: 0.0807 - val_mae: 0.2048
# Epoch 8/15
# 3176/3176 ━━━━━━━━━━━━━━━━━━━━ 20s 6ms/step - loss: 0.0489 - mae: 0.1562 - val_loss: 0.0809 - val_mae: 0.1992
# Epoch 9/15
# 3176/3176 ━━━━━━━━━━━━━━━━━━━━ 21s 7ms/step - loss: 0.0463 - mae: 0.1526 - val_loss: 0.0805 - val_mae: 0.1985
# Epoch 10/15
# 3176/3176 ━━━━━━━━━━━━━━━━━━━━ 23s 7ms/step - loss: 0.0441 - mae: 0.1496 - val_loss: 0.0831 - val_mae: 0.2057
# Epoch 11/15
# 3176/3176 ━━━━━━━━━━━━━━━━━━━━ 20s 6ms/step - loss: 0.0417 - mae: 0.1463 - val_loss: 0.0839 - val_mae: 0.2036
# Epoch 12/15
# 3176/3176 ━━━━━━━━━━━━━━━━━━━━ 21s 7ms/step - loss: 0.0397 - mae: 0.1435 - val_loss: 0.0851 - val_mae: 0.2032
# Epoch 13/15
# 3176/3176 ━━━━━━━━━━━━━━━━━━━━ 21s 6ms/step - loss: 0.0378 - mae: 0.1405 - val_loss: 0.0860 - val_mae: 0.2037
# Epoch 14/15
# 3176/3176 ━━━━━━━━━━━━━━━━━━━━ 20s 6ms/step - loss: 0.0361 - mae: 0.1379 - val_loss: 0.0891 - val_mae: 0.2071
# Epoch 15/15
# 3176/3176 ━━━━━━━━━━━━━━━━━━━━ 22s 7ms/step - loss: 0.0347 - mae: 0.1356 - val_loss: 0.0866 - val_mae: 0.2025

# %%
lstm_batch32_pred_scaled = lstm_batch32.predict(
    X_test_seq,
    batch_size=32
)

print("Prediction shape:", lstm_batch32_pred_scaled.shape)
# Out:
# 680/680 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step
# Prediction shape: (21737, 24)

# %%
lstmbatch32_pred = target_scaler.inverse_transform(
    lstm_batch32_pred_scaled.reshape(-1, 1)
).reshape(lstm_batch32_pred_scaled.shape)

lstmbatch32_actual = target_scaler.inverse_transform(
    y_test_seq.reshape(-1, 1)
).reshape(y_test_seq.shape)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

lstmb32_mae = mean_absolute_error(
    lstmbatch32_actual.flatten(),
    lstm32_pred.flatten()
)

lstmb32_rmse = np.sqrt(
    mean_squared_error(
        lstmbatch32_actual.flatten(),
        lstmbatch32_pred.flatten()
    )
)

lstmb32_mape = np.mean(
    np.abs(
        (lstmbatch32_actual.flatten() - lstmbatch32_pred.flatten())
        / lstmbatch32_actual.flatten()
    )
) * 100

lstmb32_r2 = r2_score(
    lstmbatch32_actual.flatten(),
    lstmbatch32_pred.flatten()
)

lstmb32_bias = np.mean(
    lstmbatch32_pred.flatten() -
    lstmbatch32_actual.flatten()
)

print("=== LSTM batch32 NEURONS ===")
print("MAE :", lstmb32_mae)
print("RMSE:", lstmb32_rmse)
print("MAPE:", lstmb32_mape)
print("R²  :", lstmb32_r2)
print("Bias:", lstmb32_bias)
# Out:
# === LSTM batch32 NEURONS ===
# MAE : 1464.3484043174512
# RMSE: 2154.173550570659
# MAPE: 4.614184993803667
# R²  : 0.8881911396102412
# Bias: 183.53409682098064

# %% [markdown]
# BatchSize(128)

# %%
lstm_batch128 = Sequential([
    LSTM(64, input_shape=(24, 15)),
    Dense(64, activation="relu"),
    Dense(24)
])

lstm_batch128.compile(
    optimizer="adam",
    loss="mse",
    metrics=["mae"]
)

history_batch128 = lstm_batch128.fit(
    X_train_seq,
    y_train_seq,
    validation_data=(X_val_seq, y_val_seq),
    epochs=15,
    batch_size=128,
    verbose=1
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/15
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.1442 - mae: 0.2658 - val_loss: 0.0899 - val_mae: 0.2184
# Epoch 2/15
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 0.0724 - mae: 0.1935 - val_loss: 0.0838 - val_mae: 0.2099
# Epoch 3/15
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0665 - mae: 0.1837 - val_loss: 0.0812 - val_mae: 0.2041
# Epoch 4/15
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.0627 - mae: 0.1773 - val_loss: 0.0789 - val_mae: 0.2010
# Epoch 5/15
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 0.0601 - mae: 0.1732 - val_loss: 0.0775 - val_mae: 0.1967
# Epoch 6/15
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 0.0581 - mae: 0.1699 - val_loss: 0.0755 - val_mae: 0.1939
# Epoch 7/15
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 0.0564 - mae: 0.1672 - val_loss: 0.0762 - val_mae: 0.1962
# Epoch 8/15
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0549 - mae: 0.1649 - val_loss: 0.0756 - val_mae: 0.1942
# Epoch 9/15
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 0.0536 - mae: 0.1632 - val_loss: 0.0825 - val_mae: 0.2016
# Epoch 10/15
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.0519 - mae: 0.1604 - val_loss: 0.0774 - val_mae: 0.1970
# Epoch 11/15
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0505 - mae: 0.1584 - val_loss: 0.0825 - val_mae: 0.2011
# Epoch 12/15
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 0.0491 - mae: 0.1566 - val_loss: 0.0796 - val_mae: 0.1973
# Epoch 13/15
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0478 - mae: 0.1547 - val_loss: 0.0777 - val_mae: 0.1965
# Epoch 14/15
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 0.0463 - mae: 0.1526 - val_loss: 0.0809 - val_mae: 0.1973
# Epoch 15/15
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0451 - mae: 0.1510 - val_loss: 0.0839 - val_mae: 0.2038

# %%
lstm_batch128_pred_scaled = lstm_batch128.predict(
    X_test_seq,
    batch_size=128
)

print("Prediction shape:", lstm_batch128_pred_scaled.shape)
# Out:
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Prediction shape: (21737, 24)

# %%
lstmbatch128_pred = target_scaler.inverse_transform(
    lstm_batch128_pred_scaled.reshape(-1, 1)
).reshape(lstm_batch128_pred_scaled.shape)

lstmbatch128_actual = target_scaler.inverse_transform(
    y_test_seq.reshape(-1, 1)
).reshape(y_test_seq.shape)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

lstmb128_mae = mean_absolute_error(
    lstmbatch128_actual.flatten(),
    lstmbatch128_pred.flatten()
)

lstmb128_rmse = np.sqrt(
    mean_squared_error(
        lstmbatch128_actual.flatten(),
        lstmbatch128_pred.flatten()
    )
)

lstmb128_mape = np.mean(
    np.abs(
        (lstmbatch128_actual.flatten() - lstmbatch128_pred.flatten())
        / lstmbatch128_actual.flatten()
    )
) * 100

lstmb128_r2 = r2_score(
    lstmbatch128_actual.flatten(),
    lstmbatch128_pred.flatten()
)

lstmb128_bias = np.mean(
    lstmbatch128_pred.flatten() -
    lstmbatch128_actual.flatten()
)

print("=== LSTM batch128  ===")
print("MAE :", lstmb128_mae)
print("RMSE:", lstmb128_rmse)
print("MAPE:", lstmb128_mape)
print("R²  :", lstmb128_r2)
print("Bias:", lstmb128_bias)
# Out:
# === LSTM batch128  ===
# MAE : 1473.614765763972
# RMSE: 2096.804859931053
# MAPE: 4.670255980671957
# R²  : 0.8940670975664853
# Bias: 382.6896847798636

# %% [markdown]
# **HyperParameter Tuning**

# %%
# !pip install keras-tuner
# Out:
# Collecting keras-tuner
#   Downloading keras_tuner-1.4.8-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: keras in /usr/local/lib/python3.12/dist-packages (from keras-tuner) (3.13.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from keras-tuner) (26.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from keras-tuner) (2.32.4)
# Collecting kt-legacy (from keras-tuner)
#   Downloading kt_legacy-1.0.5-py3-none-any.whl.metadata (221 bytes)
# Requirement already satisfied: grpcio in /usr/local/lib/python3.12/dist-packages (from keras-tuner) (1.82.1)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from keras-tuner) (5.29.6)
# Requirement already satisfied: typing-extensions~=4.12 in /usr/local/lib/python3.12/dist-packages (from grpcio->keras-tuner) (4.16.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from keras->keras-tuner) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from keras->keras-tuner) (2.0.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras->keras-tuner) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras->keras-tuner) (0.1.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.12/dist-packages (from keras->keras-tuner) (3.16.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras->keras-tuner) (0.19.1)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.12/dist-packages (from keras->keras-tuner) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->keras-tuner) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->keras-tuner) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->keras-tuner) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->keras-tuner) (2026.6.17)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras->keras-tuner) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras->keras-tuner) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras->keras-tuner) (0.1.2)
# Downloading keras_tuner-1.4.8-py3-none-any.whl (129 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.4/129.4 kB 5.3 MB/s eta 0:00:00
# Downloading kt_legacy-1.0.5-py3-none-any.whl (9.6 kB)
# Installing collected packages: kt-legacy, keras-tuner
# Successfully installed keras-tuner-1.4.8 kt-legacy-1.0.5

# %%
import keras_tuner as kt

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense, Dropout
from tensorflow.keras.optimizers import Adam

# %%
def build_lstm(hp):

    model = Sequential()

    model.add(
        LSTM(
            units=hp.Choice(
                "rnn_units",
                values=[32, 64, 128]
            ),
            input_shape=(24, 15)
        )
    )

    model.add(
        Dense(
            units=hp.Choice(
                "dense_units",
                values=[32, 64, 128]
            ),
            activation="relu"
        )
    )

    model.add(Dense(24))

    learning_rate = hp.Choice(
        "learning_rate",
        values=[0.0001, 0.0005, 0.001]
    )

    model.compile(
        optimizer=Adam(
            learning_rate=learning_rate
        ),
        loss="mse",
        metrics=["mae"]
    )

    return model

# %%
tuner = kt.RandomSearch(
    build_lstm,
    objective="val_loss",
    max_trials=6,
    executions_per_trial=1,
    directory="hyperparameter_tuning",
    project_name="lstm_48_to_24"
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
tuner.search(
    X_train_seq,
    y_train_seq,
    validation_data=(
        X_val_seq,
        y_val_seq
    ),
    epochs=15,
    batch_size=64,
    verbose=1
)
# Out:
# Trial 6 Complete [00h 02m 44s]
# val_loss: 0.07687690109014511
#
# Best val_loss So Far: 0.07353559136390686
# Total elapsed time: 00h 18m 06s

# %%
best_hp = tuner.get_best_hyperparameters(num_trials=1)[0]

print("BEST HYPERPARAMETERS")
print("RNN Units:",best_hp.get("rnn_units"))
print("Dense Units:",best_hp.get("dense_units"))
print("Learning Rate:",best_hp.get("learning_rate"))
# Out:
# BEST HYPERPARAMETERS
# RNN Units: 32
# Dense Units: 128
# Learning Rate: 0.0005

# %%
best_model = tuner.get_best_models(num_models=1)[0]
best_model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 16 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 32)             │         6,144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │         4,224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 24)             │         3,096 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 13,464 (52.59 KB)
#  Trainable params: 13,464 (52.59 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history_best = best_model.fit(
    X_train_seq,
    y_train_seq,
    validation_data=(
        X_val_seq,
        y_val_seq
    ),
    epochs=15,
    batch_size=64,
    verbose=1
)
# Out:
# Epoch 1/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - loss: 0.0579 - mae: 0.1691 - val_loss: 0.0795 - val_mae: 0.2005
# Epoch 2/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 0.0572 - mae: 0.1678 - val_loss: 0.0751 - val_mae: 0.1957
# Epoch 3/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 0.0565 - mae: 0.1666 - val_loss: 0.0806 - val_mae: 0.2019
# Epoch 4/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 0.0561 - mae: 0.1659 - val_loss: 0.0751 - val_mae: 0.1956
# Epoch 5/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 0.0554 - mae: 0.1649 - val_loss: 0.0795 - val_mae: 0.1991
# Epoch 6/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 0.0549 - mae: 0.1641 - val_loss: 0.0768 - val_mae: 0.1972
# Epoch 7/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 0.0548 - mae: 0.1638 - val_loss: 0.0772 - val_mae: 0.1965
# Epoch 8/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 0.0541 - mae: 0.1629 - val_loss: 0.0733 - val_mae: 0.1918
# Epoch 9/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 0.0538 - mae: 0.1624 - val_loss: 0.0727 - val_mae: 0.1896
# Epoch 10/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 0.0533 - mae: 0.1616 - val_loss: 0.0749 - val_mae: 0.1939
# Epoch 11/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 0.0530 - mae: 0.1612 - val_loss: 0.0737 - val_mae: 0.1921
# Epoch 12/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 0.0526 - mae: 0.1605 - val_loss: 0.0746 - val_mae: 0.1939
# Epoch 13/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 0.0523 - mae: 0.1601 - val_loss: 0.0754 - val_mae: 0.1931
# Epoch 14/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 0.0520 - mae: 0.1597 - val_loss: 0.0736 - val_mae: 0.1910
# Epoch 15/15
# 1588/1588 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 0.0516 - mae: 0.1591 - val_loss: 0.0739 - val_mae: 0.1933

# %%
best_pred_scaled = best_model.predict(
    X_test_seq,
    batch_size=64
)

best_pred = target_scaler.inverse_transform(
    best_pred_scaled.reshape(-1, 1)
).reshape(best_pred_scaled.shape)

best_actual = target_scaler.inverse_transform(
    y_test_seq.reshape(-1, 1)
).reshape(y_test_seq.shape)
# Out:
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step

# %%
from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    r2_score
)
import numpy as np

best_mae = mean_absolute_error(
    best_actual.flatten(),
    best_pred.flatten()
)

best_rmse = np.sqrt(
    mean_squared_error(
        best_actual.flatten(),
        best_pred.flatten()
    )
)

best_mape = np.mean(
    np.abs(
        (best_actual.flatten() - best_pred.flatten())
        / best_actual.flatten()
    )
) * 100

best_r2 = r2_score(
    best_actual.flatten(),
    best_pred.flatten()
)

best_bias = np.mean(
    best_pred.flatten() -
    best_actual.flatten()
)

print("HYPERPARAMETER TUNED LSTM")
print("MAE :", best_mae)
print("RMSE:", best_rmse)
print("MAPE:", best_mape)
print("R²  :", best_r2)
print("Bias:", best_bias)
# Out:
# HYPERPARAMETER TUNED LSTM
# MAE : 1429.862873023633
# RMSE: 2002.5690622350573
# MAPE: 4.521391137043684
# R²  : 0.9033749242463657
# Bias: 243.80461904358424

# %% [markdown]
# **Additional Logs**

# %%
# Additional lag features

PJME_data["Lag_2"] = PJME_data["PJME_MW"].shift(2)
PJME_data["Lag_3"] = PJME_data["PJME_MW"].shift(3)
PJME_data["Lag_6"] = PJME_data["PJME_MW"].shift(6)
PJME_data["Lag_12"] = PJME_data["PJME_MW"].shift(12)
PJME_data["Lag_72"] = PJME_data["PJME_MW"].shift(72)
PJME_data["Lag_336"] = PJME_data["PJME_MW"].shift(336)

# %%
PJME_data = PJME_data.dropna().copy()

print("Missing values:")
print(PJME_data.isnull().sum().sum())

print("Shape:")
print(PJME_data.shape)
# Out:
# Missing values:
# 0
# Shape:
# (144888, 21)

# %%
features = [
    "PJME_MW",
    "Hour",
    "Day",
    "Week",
    "Month",
    "DayOfWeek",
    "IsWeekend",

    "Lag_1",
    "Lag_2",
    "Lag_3",
    "Lag_6",
    "Lag_12",
    "Lag_24",
    "Lag_48",
    "Lag_72",
    "Lag_168",
    "Lag_336",

    "Rolling_Mean_24",
    "Rolling_Mean_168",
    "Rolling_Std_24",
    "Rolling_Std_168"
]

print("Number of features:", len(features))
# Out:
# Number of features: 21

# %%
n = len(PJME_data)

train_end = int(n * 0.70)
val_end = int(n * 0.85)

train_data = PJME_data.iloc[:train_end]
val_data = PJME_data.iloc[train_end:val_end]
test_data = PJME_data.iloc[val_end:]

print("Train:", train_data.shape)
print("Validation:", val_data.shape)
print("Test:", test_data.shape)
# Out:
# Train: (101421, 21)
# Validation: (21733, 21)
# Test: (21734, 21)

# %%
X_train = train_data[features]
y_train = train_data[["PJME_MW"]]

X_val = val_data[features]
y_val = val_data[["PJME_MW"]]

X_test = test_data[features]
y_test = test_data[["PJME_MW"]]

# %%
from sklearn.preprocessing import StandardScaler

feature_scaler = StandardScaler()
target_scaler = StandardScaler()

X_train_scaled = feature_scaler.fit_transform(X_train)
X_val_scaled = feature_scaler.transform(X_val)
X_test_scaled = feature_scaler.transform(X_test)

y_train_scaled = target_scaler.fit_transform(y_train)
y_val_scaled = target_scaler.transform(y_val)
y_test_scaled = target_scaler.transform(y_test)

print("Scaling completed.")
# Out:
# Scaling completed.

# %%
X_train_seq, y_train_seq = create_sequences(
    X_train_scaled,
    y_train_scaled,
    input_steps=24,
    output_steps=24
)

X_val_seq, y_val_seq = create_sequences(
    X_val_scaled,
    y_val_scaled,
    input_steps=24,
    output_steps=24
)

X_test_seq, y_test_seq = create_sequences(
    X_test_scaled,
    y_test_scaled,
    input_steps=24,
    output_steps=24
)

print("X_train:", X_train_seq.shape)
print("y_train:", y_train_seq.shape)

print("X_val:", X_val_seq.shape)
print("y_val:", y_val_seq.shape)

print("X_test:", X_test_seq.shape)
print("y_test:", y_test_seq.shape)
# Out:
# X_train: (101374, 24, 21)
# y_train: (101374, 24)
# X_val: (21686, 24, 21)
# y_val: (21686, 24)
# X_test: (21687, 24, 21)
# y_test: (21687, 24)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

lstm_lags = Sequential([
    LSTM(
        64,
        input_shape=(24, 21)
    ),

    Dense(
        64,
        activation="relu"
    ),

    Dense(24)
])

lstm_lags.compile(
    optimizer="adam",
    loss="mse",
    metrics=["mae"]
)

lstm_lags.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_1 (LSTM)                   │ (None, 64)             │        22,016 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 24)             │         1,560 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 27,736 (108.34 KB)
#  Trainable params: 27,736 (108.34 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history_lags = lstm_lags.fit(
    X_train_seq,
    y_train_seq,
    validation_data=(
        X_val_seq,
        y_val_seq
    ),
    epochs=15,
    batch_size=64,
    verbose=1
)
# Out:
# Epoch 1/15
# 1584/1584 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - loss: 0.1131 - mae: 0.2383 - val_loss: 0.0859 - val_mae: 0.2113
# Epoch 2/15
# 1584/1584 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 0.0686 - mae: 0.1874 - val_loss: 0.0801 - val_mae: 0.2063
# Epoch 3/15
# 1584/1584 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 0.0630 - mae: 0.1780 - val_loss: 0.0775 - val_mae: 0.2002
# Epoch 4/15
# 1584/1584 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 0.0596 - mae: 0.1725 - val_loss: 0.0777 - val_mae: 0.1987
# Epoch 5/15
# 1584/1584 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 0.0569 - mae: 0.1682 - val_loss: 0.0738 - val_mae: 0.1939
# Epoch 6/15
# 1584/1584 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 0.0548 - mae: 0.1650 - val_loss: 0.0780 - val_mae: 0.1997
# Epoch 7/15
# 1584/1584 ━━━━━━━━━━━━━━━━━━━━ 20s 6ms/step - loss: 0.0524 - mae: 0.1616 - val_loss: 0.0755 - val_mae: 0.1979
# Epoch 8/15
# 1584/1584 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 0.0501 - mae: 0.1583 - val_loss: 0.0759 - val_mae: 0.1925
# Epoch 9/15
# 1584/1584 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 0.0483 - mae: 0.1558 - val_loss: 0.0744 - val_mae: 0.1901
# Epoch 10/15
# 1584/1584 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 0.0463 - mae: 0.1529 - val_loss: 0.0785 - val_mae: 0.1959
# Epoch 11/15
# 1584/1584 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 0.0438 - mae: 0.1495 - val_loss: 0.0811 - val_mae: 0.1967
# Epoch 12/15
# 1584/1584 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 0.0419 - mae: 0.1469 - val_loss: 0.0796 - val_mae: 0.1952
# Epoch 13/15
# 1584/1584 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 0.0401 - mae: 0.1441 - val_loss: 0.0793 - val_mae: 0.1939
# Epoch 14/15
# 1584/1584 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 0.0386 - mae: 0.1420 - val_loss: 0.0841 - val_mae: 0.1988
# Epoch 15/15
# 1584/1584 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 0.0366 - mae: 0.1388 - val_loss: 0.0838 - val_mae: 0.2011

# %%
pred_scaled = lstm_lags.predict(
    X_test_seq,
    batch_size=64
)

print("Prediction shape:", pred_scaled.shape)
# Out:
# 339/339 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Prediction shape: (21687, 24)

# %%
pred = target_scaler.inverse_transform(
    pred_scaled.reshape(-1, 1)
).reshape(pred_scaled.shape)

actual = target_scaler.inverse_transform(
    y_test_seq.reshape(-1, 1)
).reshape(y_test_seq.shape)

# %%
from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    r2_score
)
import numpy as np

mae = mean_absolute_error(
    actual.flatten(),
    pred.flatten()
)

rmse = np.sqrt(
    mean_squared_error(
        actual.flatten(),
        pred.flatten()
    )
)

mape = np.mean(
    np.abs(
        (actual.flatten() - pred.flatten())
        / actual.flatten()
    )
) * 100

r2 = r2_score(
    actual.flatten(),
    pred.flatten()
)

bias = np.mean(
    pred.flatten() - actual.flatten()
)

print("=== LSTM + ADDITIONAL LAGS ===")
print("MAE :", mae)
print("RMSE:", rmse)
print("MAPE:", mape)
print("R²  :", r2)
print("Bias:", bias)
# Out:
# === LSTM + ADDITIONAL LAGS ===
# MAE : 1468.0982204703507
# RMSE: 2120.8439884201957
# MAPE: 4.624524339084943
# R²  : 0.8917507422669871
# Bias: 269.7069927232052

# %%
import pandas as pd
import os

lstm_24_24_results = [
    ["LSTM Baseline", 24, 24, 1491.6327254665684, 2165.564133063436, 4.693110195238567, 0.8870055943155081, 315.4325268070607],
    ["LSTM + EarlyStopping", 24, 24, 1371.5942926832286, 1966.0505445799872, 4.308456332861411, 0.9068668697446858, -7.358135540154029],
    ["LSTM + Dropout", 24, 24, 1435.9869157270186, 1978.9195155859854, 4.598822519549131, 0.9056436559322364, 292.5129554768307],
    ["LSTM + Batch Normalization", 24, 24, 1497.3504537681347, 2152.169810189539, 4.745313523054921, 0.8883990446168706, 331.9928530416228],
    ["LSTM + RMSprop", 24, 24, 1448.469909610875, 2081.2529851468817, 4.552259525724164, 0.8956326659487768, 116.74554798932144],
    ["LSTM + SGD", 24, 24, 1619.9055719913351, 2202.2063143118253, 5.131375074640218, 0.8831494261356626, 41.03663592316552],
    ["LSTM + RMSprop + Learning Rate", 24, 24, 1410.2147051636646, 1998.6879593345095, 4.457815486714933, 0.9037490920798036, 251.24647654060593],
    ["LSTM + Additional Layers", 24, 24, 1519.6695388148364, 2214.7553001711126, 4.766964569656305, 0.8818139162795469, 206.9655315675689],
    ["LSTM 128 Neurons", 24, 24, 1506.9126826623833, 1966.0505445799872, 4.712792519674344, 0.8858572879605617, 126.27973308856599],
    ["LSTM 32 Neurons", 24, 24, 1464.3484043174512, 2061.1117565050754, 4.648727127650058, 0.8976429116340158, 341.37884747145324],
    ["LSTM Batch Size 32", 24, 24, 1464.3484043174512, 2154.173550570659, 4.614184993803667, 0.8881911396102412, 183.53409682098064],
    ["LSTM Batch Size 128", 24, 24, 1473.614765763972, 2096.804859931053, 4.670255980671957, 0.8940670975664853, 382.6896847798636],
    ["LSTM Hyperparameter Tuned", 24, 24, 1429.862873023633, 2002.5690622350573, 4.521391137043684, 0.9033749242463657, 243.80461904358424],
    ["LSTM + Additional Lags", 24, 24, 1468.0982204703507, 2120.8439884201957, 4.624524339084943, 0.8917507422669871, 269.7069927232052]
]

lstm_24_24_df = pd.DataFrame(
    lstm_24_24_results,
    columns=[
        "Model",
        "Input Hours",
        "Output Hours",
        "MAE",
        "RMSE",
        "MAPE (%)",
        "R²",
        "Bias"
    ]
)

# Display with exactly 6 decimal places
display(
    lstm_24_24_df.style.format({
        "MAE": "{:.6f}",
        "RMSE": "{:.6f}",
        "MAPE (%)": "{:.6f}",
        "R²": "{:.6f}",
        "Bias": "{:.6f}"
    })
)

# Save inside existing comparison folder
os.makedirs("comparison", exist_ok=True)

lstm_24_24_df.to_csv(
    "comparison/LSTM_24h_to_24h_results.csv",
    index=False,
    float_format="%.6f"
)

print("Saved: comparison/LSTM_24h_to_24h_results.csv")
# Out:
# <style type="text/css">
# </style>
# <table id="T_d4a14">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d4a14_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_d4a14_level0_col1" class="col_heading level0 col1" >Input Hours</th>
#       <th id="T_d4a14_level0_col2" class="col_heading level0 col2" >Output Hours</th>
#       <th id="T_d4a14_level0_col3" class="col_heading level0 col3" >MAE</th>
#       <th id="T_d4a14_level0_col4" class="col_heading level0 col4" >RMSE</th>
#       <th id="T_d4a14_level0_col5" class="col_heading level0 col5" >MAPE (%)</th>
#       <th id="T_d4a14_level0_col6" class="col_heading level0 col6" >R²</th>
#       <th id="T_d4a14_level0_col7" class="col_heading level0 col7" >Bias</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d4a14_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d4a14_row0_col0" class="data row0 col0" >LSTM Baseline</td>
#       <td id="T_d4a14_row0_col1" class="data row0 col1" >24</td>
#       <td id="T_d4a14_row0_col2" class="data row0 col2" >24</td>
#       <td id="T_d4a14_row0_col3" class="data row0 col3" >1491.632725</td>
#       <td id="T_d4a14_row0_col4" class="data row0 col4" >2165.564133</td>
#       <td id="T_d4a14_row0_col5" class="data row0 col5" >4.693110</td>
#       <td id="T_d4a14_row0_col6" class="data row0 col6" >0.887006</td>
#       <td id="T_d4a14_row0_col7" class="data row0 col7" >315.432527</td>
#     </tr>
#     <tr>
#       <th id="T_d4a14_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d4a14_row1_col0" class="data row1 col0" >LSTM + EarlyStopping</td>
#       <td id="T_d4a14_row1_col1" class="data row1 col1" >24</td>
#       <td id="T_d4a14_row1_col2" class="data row1 col2" >24</td>
#       <td id="T_d4a14_row1_col3" class="data row1 col3" >1371.594293</td>
#       <td id="T_d4a14_row1_col4" class="data row1 col4" >1966.050545</td>
#       <td id="T_d4a14_row1_col5" class="data row1 col5" >4.308456</td>
#       <td id="T_d4a14_row1_col6" class="data row1 col6" >0.906867</td>
#       <td id="T_d4a14_row1_col7" class="data row1 col7" >-7.358136</td>
#     </tr>
#     <tr>
#       <th id="T_d4a14_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d4a14_row2_col0" class="data row2 col0" >LSTM + Dropout</td>
#       <td id="T_d4a14_row2_col1" class="data row2 col1" >24</td>
#       <td id="T_d4a14_row2_col2" class="data row2 col2" >24</td>
#       <td id="T_d4a14_row2_col3" class="data row2 col3" >1435.986916</td>
#       <td id="T_d4a14_row2_col4" class="data row2 col4" >1978.919516</td>
#       <td id="T_d4a14_row2_col5" class="data row2 col5" >4.598823</td>
#       <td id="T_d4a14_row2_col6" class="data row2 col6" >0.905644</td>
#       <td id="T_d4a14_row2_col7" class="data row2 col7" >292.512955</td>
#     </tr>
#     <tr>
#       <th id="T_d4a14_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d4a14_row3_col0" class="data row3 col0" >LSTM + Batch Normalization</td>
#       <td id="T_d4a14_row3_col1" class="data row3 col1" >24</td>
#       <td id="T_d4a14_row3_col2" class="data row3 col2" >24</td>
#       <td id="T_d4a14_row3_col3" class="data row3 col3" >1497.350454</td>
#       <td id="T_d4a14_row3_col4" class="data row3 col4" >2152.169810</td>
#       <td id="T_d4a14_row3_col5" class="data row3 col5" >4.745314</td>
#       <td id="T_d4a14_row3_col6" class="data row3 col6" >0.888399</td>
#       <td id="T_d4a14_row3_col7" class="data row3 col7" >331.992853</td>
#     </tr>
#     <tr>
#       <th id="T_d4a14_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d4a14_row4_col0" class="data row4 col0" >LSTM + RMSprop</td>
#       <td id="T_d4a14_row4_col1" class="data row4 col1" >24</td>
#       <td id="T_d4a14_row4_col2" class="data row4 col2" >24</td>
#       <td id="T_d4a14_row4_col3" class="data row4 col3" >1448.469910</td>
#       <td id="T_d4a14_row4_col4" class="data row4 col4" >2081.252985</td>
#       <td id="T_d4a14_row4_col5" class="data row4 col5" >4.552260</td>
#       <td id="T_d4a14_row4_col6" class="data row4 col6" >0.895633</td>
#       <td id="T_d4a14_row4_col7" class="data row4 col7" >116.745548</td>
#     </tr>
#     <tr>
#       <th id="T_d4a14_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d4a14_row5_col0" class="data row5 col0" >LSTM + SGD</td>
#       <td id="T_d4a14_row5_col1" class="data row5 col1" >24</td>
#       <td id="T_d4a14_row5_col2" class="data row5 col2" >24</td>
#       <td id="T_d4a14_row5_col3" class="data row5 col3" >1619.905572</td>
#       <td id="T_d4a14_row5_col4" class="data row5 col4" >2202.206314</td>
#       <td id="T_d4a14_row5_col5" class="data row5 col5" >5.131375</td>
#       <td id="T_d4a14_row5_col6" class="data row5 col6" >0.883149</td>
#       <td id="T_d4a14_row5_col7" class="data row5 col7" >41.036636</td>
#     </tr>
#     <tr>
#       <th id="T_d4a14_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d4a14_row6_col0" class="data row6 col0" >LSTM + RMSprop + Learning Rate</td>
#       <td id="T_d4a14_row6_col1" class="data row6 col1" >24</td>
#       <td id="T_d4a14_row6_col2" class="data row6 col2" >24</td>
#       <td id="T_d4a14_row6_col3" class="data row6 col3" >1410.214705</td>
#       <td id="T_d4a14_row6_col4" class="data row6 col4" >1998.687959</td>
#       <td id="T_d4a14_row6_col5" class="data row6 col5" >4.457815</td>
#       <td id="T_d4a14_row6_col6" class="data row6 col6" >0.903749</td>
#       <td id="T_d4a14_row6_col7" class="data row6 col7" >251.246477</td>
#     </tr>
#     <tr>
#       <th id="T_d4a14_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d4a14_row7_col0" class="data row7 col0" >LSTM + Additional Layers</td>
#       <td id="T_d4a14_row7_col1" class="data row7 col1" >24</td>
#       <td id="T_d4a14_row7_col2" class="data row7 col2" >24</td>
#       <td id="T_d4a14_row7_col3" class="data row7 col3" >1519.669539</td>
#       <td id="T_d4a14_row7_col4" class="data row7 col4" >2214.755300</td>
#       <td id="T_d4a14_row7_col5" class="data row7 col5" >4.766965</td>
#       <td id="T_d4a14_row7_col6" class="data row7 col6" >0.881814</td>
#       <td id="T_d4a14_row7_col7" class="data row7 col7" >206.965532</td>
#     </tr>
#     <tr>
#       <th id="T_d4a14_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d4a14_row8_col0" class="data row8 col0" >LSTM 128 Neurons</td>
#       <td id="T_d4a14_row8_col1" class="data row8 col1" >24</td>
#       <td id="T_d4a14_row8_col2" class="data row8 col2" >24</td>
#       <td id="T_d4a14_row8_col3" class="data row8 col3" >1506.912683</td>
#       <td id="T_d4a14_row8_col4" class="data row8 col4" >1966.050545</td>
#       <td id="T_d4a14_row8_col5" class="data row8 col5" >4.712793</td>
#       <td id="T_d4a14_row8_col6" class="data row8 col6" >0.885857</td>
#       <td id="T_d4a14_row8_col7" class="data row8 col7" >126.279733</td>
#     </tr>
#     <tr>
#       <th id="T_d4a14_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d4a14_row9_col0" class="data row9 col0" >LSTM 32 Neurons</td>
#       <td id="T_d4a14_row9_col1" class="data row9 col1" >24</td>
#       <td id="T_d4a14_row9_col2" class="data row9 col2" >24</td>
#       <td id="T_d4a14_row9_col3" class="data row9 col3" >1464.348404</td>
#       <td id="T_d4a14_row9_col4" class="data row9 col4" >2061.111757</td>
#       <td id="T_d4a14_row9_col5" class="data row9 col5" >4.648727</td>
#       <td id="T_d4a14_row9_col6" class="data row9 col6" >0.897643</td>
#       <td id="T_d4a14_row9_col7" class="data row9 col7" >341.378847</td>
#     </tr>
#     <tr>
#       <th id="T_d4a14_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_d4a14_row10_col0" class="data row10 col0" >LSTM Batch Size 32</td>
#       <td id="T_d4a14_row10_col1" class="data row10 col1" >24</td>
#       <td id="T_d4a14_row10_col2" class="data row10 col2" >24</td>
#       <td id="T_d4a14_row10_col3" class="data row10 col3" >1464.348404</td>
#       <td id="T_d4a14_row10_col4" class="data row10 col4" >2154.173551</td>
#       <td id="T_d4a14_row10_col5" class="data row10 col5" >4.614185</td>
# Saved: comparison/LSTM_24h_to_24h_results.csv

# %%
best_lstm_24_24 = lstm_24_24_df.loc[lstm_24_24_df["Model"] == "LSTM + EarlyStopping"]
display(best_lstm_24_24.style.format({
        "MAE": "{:.6f}",
        "RMSE": "{:.6f}",
        "MAPE (%)": "{:.6f}",
        "R²": "{:.6f}",
        "Bias": "{:.6f}"
    })
)
# Out:
# <style type="text/css">
# </style>
# <table id="T_1b8c7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1b8c7_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_1b8c7_level0_col1" class="col_heading level0 col1" >Input Hours</th>
#       <th id="T_1b8c7_level0_col2" class="col_heading level0 col2" >Output Hours</th>
#       <th id="T_1b8c7_level0_col3" class="col_heading level0 col3" >MAE</th>
#       <th id="T_1b8c7_level0_col4" class="col_heading level0 col4" >RMSE</th>
#       <th id="T_1b8c7_level0_col5" class="col_heading level0 col5" >MAPE (%)</th>
#       <th id="T_1b8c7_level0_col6" class="col_heading level0 col6" >R²</th>
#       <th id="T_1b8c7_level0_col7" class="col_heading level0 col7" >Bias</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1b8c7_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_1b8c7_row0_col0" class="data row0 col0" >LSTM + EarlyStopping</td>
#       <td id="T_1b8c7_row0_col1" class="data row0 col1" >24</td>
#       <td id="T_1b8c7_row0_col2" class="data row0 col2" >24</td>
#       <td id="T_1b8c7_row0_col3" class="data row0 col3" >1371.594293</td>
#       <td id="T_1b8c7_row0_col4" class="data row0 col4" >1966.050545</td>
#       <td id="T_1b8c7_row0_col5" class="data row0 col5" >4.308456</td>
#       <td id="T_1b8c7_row0_col6" class="data row0 col6" >0.906867</td>
#       <td id="T_1b8c7_row0_col7" class="data row0 col7" >-7.358136</td>
#     </tr>
#   </tbody>
# </table>
